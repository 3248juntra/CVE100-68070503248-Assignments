# %% [markdown]
# CHALLENGE INSTRUCTIONS:
# - Each exercise contains one or more bugs
# - Some bugs are subtle and require careful analysis
# - Read error messages carefully - they're your best friend!
# - Some exercises have multiple bugs - fix them all!
# - Try to understand WHY the bug occurred, not just HOW to fix it
#
# Good luck!

# %% [markdown]
# **CHALLENGE 1: The Mysterious Growing List**

# %%
def add_student(name, class_list=[]):
    """Add a student to a class list"""
    class_list.append(name)
    return class_list


print("\n--- TEST CASES ---")
print("Test 1: Class A:", add_student("Alice"))
print("Test 2: Class B:", add_student("Bob"))
print("Test 3: Class C:", add_student("Charlie"))

# %% [markdown]
# **EXPECTED OUTPUT**
#
# "Class A: ['Alice']"
#
# "Class B: ['Bob']
#
# "Class C: ['Charlie']"

# %% [markdown]
# **CHALLENGE 2: The Mysterious Growing List**

# %%
total = 0

def add_to_total(value):
    # This creates a LOCAL variable named 'total'
    # instead of modifying the global one
    try:
        total = 0
        total = total + value
        return total
    except UnboundLocalError as e:
        return f"ERROR: {e}"

# %%
total_v2 = 0
print(f"Initial total: {total_v2}")
total_v2 = add_to_total(total_v2, 10)
print(f"After adding 10: {total_v2}")
total_v2 = add_to_total(total_v2, 20)
print(f"After adding 20: {total_v2}")
# Out:
# Initial total: 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1054120748.py in <cell line: 0>()
#       1 total_v2 = 0
#       2 print(f"Initial total: {total_v2}")
# ----> 3 total_v2 = add_to_total(total_v2, 10)
#       4 print(f"After adding 10: {total_v2}")
#       5 total_v2 = add_to_total(total_v2, 20)
#
# TypeError: add_to_total() takes 1 positional argument but 2 were given

# %% [markdown]
# **EXPECTED OUTPUT**
#
#
# "Initial total: 0"
#
# "After adding 10: 10"
#
# "After adding 20: 30"
#
# "Global total: 30"

# %% [markdown]
# **CHALLENGE 3: Analyze Test Scores**

# %%
def analyze_test_scores(scores):
    total = 0
    for score in scores:
        total += score

    average = total / len(scores)
    highest = scores[0]
    lowest = scores[0]
    passing_count = 0

    for i in range(len(scores)):
        if scores[i] > highest:
            highest = scores[i]
        if scores[i] < lowest:
            lowest = scores[i]
        if scores[i] >= 60:
            passing_count += 1

    return {
        'average': average,
        'highest': highest,
        'lowest': lowest,
        'passing': passing_count,
        'failing': len(scores) - passing_count
    }

# %%
print("\n--- TEST CASES ---")
test_scores = [85, 92, 78, 90, 65, 88, 76, 95, 82, 70]
print(f"Input: {test_scores}")

stats = analyze_test_scores(test_scores)
print(f"Result: {stats}")
# Out:
# --- TEST CASES ---
# Input: [85, 92, 78, 90, 65, 88, 76, 95, 82, 70]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3005084444.py in <cell line: 0>()
#       3 print(f"Input: {test_scores}")
#       4
# ----> 5 stats = analyze_test_scores(test_scores)
#       6 print(f"Result: {stats}")
#
# /tmp/ipython-input-2271231855.py in analyze_test_scores(scores)
#      11     for i in range(len(scores)):
#      12         if scores[i] > highest:
# ---> 13             highest = score[i]
#      14         if scores[i] < lowest:
#      15             lowest = scores[i]
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# {
#     'average': 82.1,
#
#     'highest': 95,
#
#     'lowest': 65,
#
#     'passing': 10,
#
#     'failing': 0
# }

# %% [markdown]
# **CHALLENGE 4: Dictionary Iteration Modification**

# %%
def remove_negative_prices(inventory):
    for item, price in inventory.items():
        if price < 0:
            del inventory[item]
    return inventory


print("\n--- TEST CASES ---")
products = {
    'apple': 1.50,
    'banana': -0.50,
    'orange': 2.00,
    'grape': -1.00,
    'mango': 3.00
}



cleaned = remove_negative_prices(products.copy())
print(f"Result: {cleaned}")
# Out:
# --- TEST CASES ---
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1281635060.py in <cell line: 0>()
#      17
#      18
# ---> 19 cleaned = remove_negative_prices(products.copy())
#      20 print(f"Result: {cleaned}")
#
# /tmp/ipython-input-1281635060.py in remove_negative_prices(inventory)
#       1 def remove_negative_prices(inventory):
# ----> 2     for item, price in inventory.items():
#       3         if price < 0:
#       4             del inventory[item]
#       5     return inventory
#
# RuntimeError: dictionary changed size during iteration

# %% [markdown]
# **EXPECTED OUTPUT**
#
#
# Result: {'apple': 1.50, 'orange': 2.00, 'mango': 3.00}
